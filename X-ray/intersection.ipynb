# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
from scipy.odr import *
from scipy.stats import linregress
from scipy.optimize import fsolve
import random




import pylab
import pandas

colnames = ['A1', 'B1']
data = pandas.read_excel("15_kv.xlsx",  names=colnames)
icc = data.A1.tolist()
vcc = data.B1.tolist()
angle=icc[58:63]  # arrange where we get th data
intens=vcc[58:63]
angle=np.array(angle)
intens=np.array(intens)


n = len(angle)                       #the number of data
mean = sum(angle)/n                   #note this correction
sigma = np.sqrt(sum((angle-mean)**2)/n)       #note this correction


def fit_func(p, x):
    m ,c= p
    return m*x+c

linear = Model(fit_func)

data = RealData(angle, intens, sy=np.sqrt(angle))

odr= ODR(data, linear, beta0=[0., -1.])

out = odr.run()

out.pprint()

x_fit = np.linspace(angle[0]-0.5, angle[-1]+0.5, 1000)
y_fit = fit_func(out.beta, x_fit)



plt.errorbar(angle, intens, xerr=0, yerr=np.sqrt(intens), linestyle='None', marker='x',ecolor='r')
plt.xlabel('Angle Theta[Degrees]')
plt.ylabel('Intensity of reflected X-ray [Imp/s]')
plt.plot(icc[:100], vcc[:100],'b.')
plt.plot(x_fit,y_fit,'g-')


plt.show()

print('intercection of x-line[degree]',-out.beta[1]/out.beta[0])
print('sigma[degree]',np.sqrt((out.sd_beta[1]/out.beta[0])**2+((out.beta[1]*out.sd_beta[0])/out.beta[0]**2)**2))
print('intercection of x-line[radian]',-(np.deg2rad(out.beta[1])/out.beta[0]))
print('sigma[radian]',np.sqrt((np.deg2rad(out.sd_beta[1])/out.beta[0])**2+((np.deg2rad(out.beta[1])*out.sd_beta[0])/out.beta[0]**2)**2))
# Out:
# Beta: [  32.74311872 -286.16236656]
# Beta Std Error: [ 2.89354651 26.33432934]
# Beta Covariance: [[  11061.44874606 -100658.98566318]
#  [-100658.98566318  916211.21076928]]
# Residual Variance: 0.0007569181580504525
# Inverse Condition #: 0.007373535066515752
# Reason(s) for Halting:
#   Sum of squares convergence
# <img src="data:image/png;base64,..." width="640">
# intercection of x-line[degree] 8.739618513623435
# sigma[degree] 1.115053763383352
# intercection of x-line[radian] 0.15253511843098186
# sigma[radian] 0.019461359507793277

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
from scipy.odr import *
from scipy.stats import linregress
from scipy.optimize import fsolve
import random




import pylab
import pandas

colnames = ['A1', 'B1']
data = pandas.read_excel("18_kv.xlsx",  names=colnames)
icc = data.A1.tolist()
vcc = data.B1.tolist()
angle=icc[43:50]  # arrange where we get th data
intens=vcc[43:50]
angle=np.array(angle)
intens=np.array(intens)


n = len(angle)                       #the number of data
mean = sum(angle)/n                   #note this correction
sigma = np.sqrt(sum((angle-mean)**2)/n)       #note this correction


def fit_func(p, x):
    m ,c= p
    return m*x+c

linear = Model(fit_func)

data = RealData(angle, intens, sy=np.sqrt(angle))

odr= ODR(data, linear, beta0=[0., -1.])

out = odr.run()

out.pprint()

x_fit = np.linspace(angle[0]-0.5, angle[-1]+0.5, 1000)
y_fit = fit_func(out.beta, x_fit)



plt.errorbar(angle, intens, xerr=0, yerr=np.sqrt(intens), linestyle='None', marker='x',ecolor='r')
plt.xlabel('Angle Theta[Degrees]')
plt.ylabel('Intensity of reflected X-ray [Imp/s]')
plt.plot(icc[:100], vcc[:100],'b.')
plt.plot(x_fit,y_fit,'g-')


plt.show()


print('intercection of x-line[degree]',-out.beta[1]/out.beta[0])
print('sigma[degree]',np.sqrt((out.sd_beta[1]/out.beta[0])**2+((out.beta[1]*out.sd_beta[0])/out.beta[0]**2)**2))
print('intercection of x-line[radian]',-(np.deg2rad(out.beta[1])/out.beta[0]))
print('sigma[radian]',np.sqrt((np.deg2rad(out.sd_beta[1])/out.beta[0])**2+((np.deg2rad(out.beta[1])*out.sd_beta[0])/out.beta[0]**2)**2))
# Out:
# Beta: [  36.49182703 -262.41559507]
# Beta Std Error: [ 3.37920637 26.02821188]
# Beta Covariance: [[  4986.26353085 -38394.08767416]
#  [-38394.08767416 295824.72164985]]
# Residual Variance: 0.002290098711627358
# Inverse Condition #: 0.011188329178191117
# Reason(s) for Halting:
#   Sum of squares convergence
# <img src="data:image/png;base64,..." width="640">
# intercection of x-line[degree] 7.19107856175203
# sigma[degree] 0.9757935589595959
# intercection of x-line[radian] 0.1255079976721513
# sigma[radian] 0.01703081042359836

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
from scipy.odr import *
from scipy.stats import linregress
from scipy.optimize import fsolve
import random




import pylab
import pandas

colnames = ['A1', 'B1']
data = pandas.read_excel("21_kv.xlsx",  names=colnames)
icc = data.A1.tolist()
vcc = data.B1.tolist()
angle=icc[34:40]  # arrange where we get th data
intens=vcc[34:40]
angle=np.array(angle)
intens=np.array(intens)


n = len(angle)                       #the number of data
mean = sum(angle)/n                   #note this correction
sigma = np.sqrt(sum((angle-mean)**2)/n)       #note this correction


def fit_func(p, x):
    m ,c= p
    return m*x+c

linear = Model(fit_func)

data = RealData(angle, intens, sy=np.sqrt(angle))

odr= ODR(data, linear, beta0=[0., -1.])

out = odr.run()

out.pprint()

x_fit = np.linspace(angle[0]-0.5, angle[-1]+0.5, 1000)
y_fit = fit_func(out.beta, x_fit)



plt.errorbar(angle, intens, xerr=0, yerr=np.sqrt(intens), linestyle='None', marker='x',ecolor='r')
plt.xlabel('Angle Theta[Degrees]')
plt.ylabel('Intensity of reflected X-ray [Imp/s]')
plt.plot(icc[:100], vcc[:100],'b.')
plt.plot(x_fit,y_fit,'g-')
plt.savefig('yevdsdllow.jpg')

plt.show()

print('intercection of x-line[degree]',-out.beta[1]/out.beta[0])
print('sigma[degree]',np.sqrt((out.sd_beta[1]/out.beta[0])**2+((out.beta[1]*out.sd_beta[0])/out.beta[0]**2)**2))
print('intercection of x-line[radian]',-(np.deg2rad(out.beta[1])/out.beta[0]))
print('sigma[radian]',np.sqrt((np.deg2rad(out.sd_beta[1])/out.beta[0])**2+((np.deg2rad(out.beta[1])*out.sd_beta[0])/out.beta[0]**2)**2))
# Out:
# Beta: [  46.2948995  -286.65721101]
# Beta Std Error: [ 4.93733428 33.33714628]
# Beta Covariance: [[ 12840.82956632 -86675.43221137]
#  [-86675.43221137 585416.3656965 ]]
# Residual Variance: 0.0018984186082063054
# Inverse Condition #: 0.010071541269270522
# Reason(s) for Halting:
#   Sum of squares convergence
# <img src="data:image/png;base64,..." width="640">
# intercection of x-line[degree] 6.191982574720398
# sigma[degree] 0.9770578276727836
# intercection of x-line[radian] 0.10807048315498674
# sigma[radian] 0.01705287607527344

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
from scipy.odr import *
from scipy.stats import linregress
from scipy.optimize import fsolve
import random




import pylab
import pandas

colnames = ['A1', 'B1']
data = pandas.read_excel("24_kv.xlsx",  names=colnames)
icc = data.A1.tolist()
vcc = data.B1.tolist()
angle=icc[26:33]  # arrange where we get th data
intens=vcc[26:33]
angle=np.array(angle)
intens=np.array(intens)


n = len(angle)                       #the number of data
mean = sum(angle)/n                   #note this correction
sigma = np.sqrt(sum((angle-mean)**2)/n)       #note this correction


def fit_func(p, x):
    m ,c= p
    return m*x+c

linear = Model(fit_func)

data = RealData(angle, intens, sy=np.sqrt(angle))

odr= ODR(data, linear, beta0=[0., -1.])

out = odr.run()

out.pprint()

x_fit = np.linspace(angle[0]-0.5, angle[-1]+0.5, 1000)
y_fit = fit_func(out.beta, x_fit)



plt.errorbar(angle, intens, xerr=0, yerr=np.sqrt(intens), linestyle='None', marker='x',ecolor='r')
plt.xlabel('Angle Theta[Degrees]')
plt.ylabel('Intensity of reflected X-ray [Imp/s]')
plt.plot(icc[:100], vcc[:100],'b.')
plt.plot(x_fit,y_fit,'g-')


plt.show()


print('intercection of x-line[degree]',-out.beta[1]/out.beta[0])
print('sigma[degree]',np.sqrt((out.sd_beta[1]/out.beta[0])**2+((out.beta[1]*out.sd_beta[0])/out.beta[0]**2)**2))
print('intercection of x-line[radian]',-(np.deg2rad(out.beta[1])/out.beta[0]))
print('sigma[radian]',np.sqrt((np.deg2rad(out.sd_beta[1])/out.beta[0])**2+((np.deg2rad(out.beta[1])*out.sd_beta[0])/out.beta[0]**2)**2))
# Out:
# Beta: [  57.55287135 -313.17436602]
# Beta Std Error: [ 2.18205096 13.09949924]
# Beta Covariance: [[ 11936.05561455 -71616.18957214]
#  [-71616.18957214 430170.32032761]]
# Residual Variance: 0.0003989045085716754
# Inverse Condition #: 0.012608675468485606
# Reason(s) for Halting:
#   Sum of squares convergence
# <img src="data:image/png;base64,..." width="640">
# intercection of x-line[degree] 5.441507238274837
# sigma[degree] 0.3071947874547437
# intercection of x-line[radian] 0.09497221757899951
# sigma[radian] 0.005361560486049449

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
from scipy.odr import *
from scipy.stats import linregress
from scipy.optimize import fsolve
import random




import pylab
import pandas

colnames = ['A1', 'B1']
data = pandas.read_excel("27_kv.xlsx",  names=colnames)
icc = data.A1.tolist()
vcc = data.B1.tolist()
angle=icc[19:26]  # arrange where we get th data
intens=vcc[19:26]
angle=np.array(angle)
intens=np.array(intens)


n = len(angle)                       #the number of data
mean = sum(angle)/n                   #note this correction
sigma = np.sqrt(sum((angle-mean)**2)/n)       #note this correction


def fit_func(p, x):
    m ,c= p
    return m*x+c

linear = Model(fit_func)

data = RealData(angle, intens, sy=np.sqrt(angle))

odr= ODR(data, linear, beta0=[0., -1.])

out = odr.run()

out.pprint()

x_fit = np.linspace(angle[0]-0.5, angle[-1]+0.5, 1000)
y_fit = fit_func(out.beta, x_fit)



plt.errorbar(angle, intens, xerr=0, yerr=np.sqrt(intens), linestyle='None', marker='x',ecolor='r')
plt.xlabel('Angle Theta[Degrees]')
plt.ylabel('Intensity of reflected X-ray [Imp/s]')
plt.plot(icc[:100], vcc[:100],'b.')
plt.plot(x_fit,y_fit,'g-')

plt.show()



print('intercection of x-line[degree]',-out.beta[1]/out.beta[0])
print('sigma[degree]',np.sqrt((out.sd_beta[1]/out.beta[0])**2+((out.beta[1]*out.sd_beta[0])/out.beta[0]**2)**2))
print('intercection of x-line[radian]',-(np.deg2rad(out.beta[1])/out.beta[0]))
print('sigma[radian]',np.sqrt((np.deg2rad(out.sd_beta[1])/out.beta[0])**2+((np.deg2rad(out.beta[1])*out.sd_beta[0])/out.beta[0]**2)**2))
# Out:
# Beta: [  40.12746476 -177.38983697]
# Beta Std Error: [ 1.98655684 10.53610657]
# Beta Covariance: [[  5839.83031973 -30950.95801379]
#  [-30950.95801379 164270.10889205]]
# Residual Variance: 0.000675774444634437
# Inverse Condition #: 0.01315977955699302
# Reason(s) for Halting:
#   Sum of squares convergence
# <img src="data:image/png;base64,..." width="640">
# intercection of x-line[degree] 4.420658968305822
# sigma[degree] 0.3418130352007156
# intercection of x-line[radian] 0.07715505410475225
# sigma[radian] 0.005965762890487764

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
from scipy.odr import *
from scipy.stats import linregress
from scipy.optimize import fsolve
import random




import pylab
import pandas

colnames = ['A1', 'B1']
data = pandas.read_excel("30_kv.xlsx",  names=colnames)
icc = data.A1.tolist()
vcc = data.B1.tolist()
angle=icc[15:22]  # arrange where we get th data
intens=vcc[15:22]
angle=np.array(angle)
intens=np.array(intens)


n = len(angle)                       #the number of data
mean = sum(angle)/n                   #note this correction
sigma = np.sqrt(sum((angle-mean)**2)/n)       #note this correction


def fit_func(p, x):
    m ,c= p
    return m*x+c

linear = Model(fit_func)

data = RealData(angle, intens, sy=np.sqrt(angle))

odr= ODR(data, linear, beta0=[0., -1.])

out = odr.run()

out.pprint()

x_fit = np.linspace(angle[0]-0.5, angle[-1]+0.5, 1000)
y_fit = fit_func(out.beta, x_fit)



plt.errorbar(angle, intens, xerr=0, yerr=np.sqrt(intens), linestyle='None', marker='x',ecolor='r')
plt.xlabel('Angle Theta[Degrees]')
plt.ylabel('Intensity of reflected X-ray [Imp/s]')
plt.plot(icc[:100], vcc[:100],'b.')
plt.plot(x_fit,y_fit,'g-')

plt.savefig('yedfvdfvdvllow.jpg')
plt.show()



print('intercection of x-line[degree]',-out.beta[1]/out.beta[0])
print('sigma[degree]',np.sqrt((out.sd_beta[1]/out.beta[0])**2+((out.beta[1]*out.sd_beta[0])/out.beta[0]**2)**2))
print('intercection of x-line[radian]',-(np.deg2rad(out.beta[1])/out.beta[0]))
print('sigma[radian]',np.sqrt((np.deg2rad(out.sd_beta[1])/out.beta[0])**2+((np.deg2rad(out.beta[1])*out.sd_beta[0])/out.beta[0]**2)**2))
# Out:
# Beta: [  63.72680882 -252.40416609]
# Beta Std Error: [ 8.77453064 43.02783039]
# Beta Covariance: [[ 15894.65562935 -77883.6720014 ]
#  [-77883.6720014  382210.16194125]]
# Residual Variance: 0.004843916704842748
# Inverse Condition #: 0.012992371924019442
# Reason(s) for Halting:
#   Sum of squares convergence
# <img src="data:image/png;base64,..." width="640">
# intercection of x-line[degree] 3.9607218806088533
# sigma[degree] 0.867923883647888
# intercection of x-line[radian] 0.06912763757240625
# sigma[radian] 0.01514812942635182

# %%
# Out:
# 5.3589793170057245e-08
