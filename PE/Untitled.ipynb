# %%
a=0.05
v=[]
for i in range (10):
    v.append(round(a+0.05*i,2))
print(v)

# %%
v=[0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5]

# %%
import numpy as np
from math import log10,floor

def round_sig(x, sig=2):     #this function calculate after zeros
    return round(x, sig-int(floor(log10(abs(x))))-1)

i=[16,12,8,6,4,2.6,1.4,0.2,-0.6,-2]
b=[]
for c in range(len(i)):
    b.append(round_sig(1e-14*i[c]))
print(b)

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook
import numpy as np


plt.plot(v, i, 'go')
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook
import numpy as np
from scipy.stats import linregress

v=[0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5]
i=[1.6e-13, 1.2e-13, 8e-14, 6e-14, 4e-14, 2.6e-14, 1.4e-14, 2e-15, -6e-15, -2e-14]
ve=[0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.001]
ie=[2e-14, 2e-14, 2e-14, 2e-14, 2e-14, 2e-15, 2e-15, 2e-15, 2e-15, 2e-14]

vp=v[:8]
ip=i[:8]

vne=v[8:]
ine=i[8:]


fit = np.polyfit(vp, ip, 1)  
yp1f = np.poly1d(fit)

fit2=np.polyfit(vne, ine, 1) 

yn1f = np.poly1d(fit2)

plt.plot(vne, yn1f(vne), '-')
plt.plot(vp, yp1f(vp), '-')


plt.errorbar(v, i,xerr=ve,yerr=ie,fmt='.',ecolor='r',ls='none')
#plt.errorbar(v, i,xerr=ve,yerr=ie,marker=',', mfc='red', ms=2)
slope, intercept, r_value, p_value, std_err1 = linregress(vne,ine)
plt.show()



plt.xlabel('Retarding Potential (Volt)')
plt.ylabel('Photocell Current (A) x 10^13')
print(slope)
print(r_value)
print(p_value)
print(std_err1)
print(fit2)
# Out:
# <img src="data:image/png;base64,..." width="640">
# -2.8e-13
# -0.9999999999999999
# 0.0
# 0.0
# [-2.8e-13  1.2e-13]

# %%
import numpy as np
from math import log10,floor

def round_sig(x, sig=2):     #this function calculate after zeros
    return round(x, sig-int(floor(log10(abs(x))))-1)

k=[]
ierr=[2,2,2,2,2,0.2,0.2,0.2,0.2,2]
for c in range(len(ierr)):
    k.append(round_sig(1e-14*ierr[c]))
print(k)

# %%
Vs = data.A1.tolist()
I = data.B1.tolist()



Is= 1e10*np.array(I)


xerr = [0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001]
yerr=[200,200,200,200,20,20,20,20,20,2,2,2,20,20,20]
Ip1=Is[0:10]
Vp1=Vs[0:10]


In1=Is[10:]
Vn1=Vs[10:]

fit = np.polyfit(Vp1, Ip1, 1)  
yp1f = np.poly1d(fit)

fit2=np.polyfit(Vn1, In1, 1) 

yn1f = np.poly1d(fit2)

plt.plot(Vn1, yn1f(Vn1), '-')
plt.plot(Vp1, yp1f(Vp1), '-')

plt.errorbar(Vs, Is,  xerr = xerr,yerr=yerr, fmt='o', ls='none') 


slope, intercept, r_value, p_value, std_err1 = linregress(Vn1,In1)


plt.xlabel('Retarding Potential (Volt)')
plt.ylabel('Photocell Current (A) x 10^10')
print(slope)
print(r_value)
print(p_value)
print(std_err1)
print(fit2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-2acb61aeb7e0> in <module>
# ----> 1 Vs = data.A1.tolist()
#       2 I = data.B1.tolist()
#       3
#       4
#       5
#
# NameError: name 'data' is not defined

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
from scipy.odr import *
from scipy.stats import linregress
import random



v=[0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5]
i=[1.6e-13, 1.2e-13, 8e-14, 6e-14, 4e-14, 2.6e-14, 1.4e-14, 2e-15, -6e-15, -2e-14]
ve=[0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.001]
ie=[2e-14, 2e-14, 2e-14, 2e-14, 2e-14, 2e-15, 2e-15, 2e-15, 2e-15, 2e-14]


mid=8

vp=v[:8]
ip=i[:8]

vne=v[8:]
ine=i[8:]


fit = np.polyfit(v[:mid], i[:mid], 1)  
yp1f = np.poly1d(fit)

fit2=np.polyfit(v[mid:], i[mid:], 1) 

yn1f = np.poly1d(fit2)

plt.plot(v[mid:], yn1f(v[mid:]), '-')
plt.plot(v[:mid], yp1f(v[:mid]), '-')



# Define a function (quadratic in our case) to fit the data with.
def fit_func(p, x):
    m, c = p
    return m*x + c

# Create a model for fitting.
fit_model = Model(fit_func)

# Create a RealData object using our initiated data from above.
data1 = RealData(v[:mid], i[:mid], sx=ve[:mid], sy=ie[:mid])
data2 = RealData(v[mid:], i[mid:], sx=ve[mid:], sy=ie[mid:])
# Set up ODR with the model and data.
odr1 = ODR(data1, fit_model, beta0=[0., 1.])
odr2 = ODR(data2, fit_model, beta0=[0., 1.])

# Run the regression.
out1 = odr1.run()
out2 = odr2.run()

# Use the in-built pprint method to give us results.
out1.pprint()
out2.pprint()
'''Beta: [ 1.01781493  0.48498006]
Beta Std Error: [ 0.00390799  0.03660941]
Beta Covariance: [[ 0.00241322 -0.01420883]
 [-0.01420883  0.21177597]]
Residual Variance: 0.00632861634898189
Inverse Condition #: 0.4195196193536024
Reason(s) for Halting:
  Sum of squares convergence'''

xp_fit = np.linspace(v[0], v[mid-1], 1000)
xn_fit = np.linspace(i[mid], i[-1], 1000)
yp_fit = fit_func(out1.beta, xp_fit)
yn_fit = fit_func(out2.beta, xn_fit)

plt.errorbar(v, i, xerr=ve, yerr=ie, linestyle='None', marker='x',ecolor='r')
plt.plot(xp_fit, yp_fit)
plt.plot(xn_fit, yn_fit)

plt.show()


slope, intercept, r_value, p_value, std_err1 = linregress(v[mid:],i[mid:])
print(slope)
print(r_value)
print(p_value)
print(std_err1)
# Out:
# <img src="data:image/png;base64,..." width="640">
# Beta: [-2.94287297e-13  1.17320979e-13]
# Beta Std Error: [3.71584271e-14 1.30081902e-14]
# Beta Covariance: [[ 5.65552953e-28 -1.96062890e-28]
#  [-1.96062890e-28  6.93094399e-29]]
# Residual Variance: 2.441413660881375
# Inverse Condition #: 0.004725480756254986
# Reason(s) for Halting:
#   Sum of squares convergence
# Beta: [-2.8e-13  1.2e-13]
# Beta Std Error: [3.17179750e-28 1.42899717e-28]
# Beta Covariance: [[ 1.61662778e-25 -7.28298197e-26]
#  [-7.28298197e-26  3.28142035e-26]]
# Residual Variance: 6.223015277861144e-31
# Inverse Condition #: 0.00047841827850528804
# Reason(s) for Halting:
#   Parameter convergence
# -2.8e-13
# -0.9999999999999999
# 0.0
# 0.0

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.odr import *

import random





# Initiate some data, giving some randomness using random.random().
x = np.array([0, 1, 2, 3, 4, 5])
y = np.array([i**2 + random.random() for i in x])
z = np.array([0, 1.3, 2.1, 2.8, 4, 5.8])

x_err = np.array([random.random() for i in x])
y_err = np.array([random.random() for i in x])

# Define a function (quadratic in our case) to fit the data with.
def quad_func(p, x):
    m, c = p
    return m*x + c

# Create a model for fitting.
quad_model = Model(quad_func)

# Create a RealData object using our initiated data from above.
data = RealData(x, z, sx=x_err, sy=y_err)

# Set up ODR with the model and data.
odr = ODR(data, quad_model, beta0=[0., 1.])

# Run the regression.
out = odr.run()

# Use the in-built pprint method to give us results.
out.pprint()
'''Beta: [ 1.01781493  0.48498006]
Beta Std Error: [ 0.00390799  0.03660941]
Beta Covariance: [[ 0.00241322 -0.01420883]
 [-0.01420883  0.21177597]]
Residual Variance: 0.00632861634898189
Inverse Condition #: 0.4195196193536024
Reason(s) for Halting:
  Sum of squares convergence'''

x_fit = np.linspace(x[0], x[-1], 1000)
y_fit = quad_func(out.beta, x_fit)

plt.errorbar(x, z, xerr=x_err, yerr=y_err, linestyle='None', marker='x')
plt.plot(x_fit, y_fit)

plt.show()
