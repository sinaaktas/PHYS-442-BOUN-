# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt


ang=[20,40,60,80,100,120,140,160,180,200,220,240,260,280,300,320,340]
dn=[28,26,36,38,64,64,68,101,86,61,69,47,43,38,27,22,13]


er = list(np.array(dn)**(1/2))
err = np.round(np.array(er),2)


plt.bar(ang, dn, width=15, align='center', color='blue',yerr=err )
plt.xlabel('Angle in degrees')
plt.ylabel('dN')


plt.show()
print(np.sqrt(dn))
print(sum(dn))
print(sum(dn)/20)
# Out:
# <img src="data:image/png;base64,..." width="640">
# [ 5.29150262  5.09901951  6.          6.164414    8.          8.
#   8.24621125 10.04987562  9.2736185   7.81024968  8.30662386  6.8556546
#   6.55743852  6.164414    5.19615242  4.69041576  3.60555128]
# 831
# 41.55

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt


ang=[20,40,60,80,100,120,140,160,180]
dn=[42,48,63,76,107,111,137,162,172]



er = list(np.array(dn)**(1/2))
err = np.round(np.array(er),2)


plt.bar(ang, dn, width=15, align='center', color='blue',yerr=err ,)
plt.xlabel('Angle in degrees')
plt.ylabel('dN')
plt.axis([10, 190, 0, 200])

plt.show()

print(np.sqrt(dn))
print(sum(dn))
print(sum(dn)/20)
# Out:
# <img src="data:image/png;base64,..." width="640">
# [ 6.4807407   6.92820323  7.93725393  8.71779789 10.34408043 10.53565375
#  11.70469991 12.72792206 13.11487705]
# 918
# 45.9

# %%
ang=[20,40,60,80,100,120,140,160,180]
dn=[42,48,63,76,107,111,137,162,172]

# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
from scipy.odr import *



xx= np.round(np.sin(np.radians(np.array(ang))/2),2)
yer= np.sqrt(np.array(dn))

def fit_func(p, x):
    m ,c= p
    return m*x+c

linear = Model(fit_func)

data = RealData(xx, dn, sy=yer)

odr= ODR(data, linear, beta0=[0., 1.])

out = odr.run()

out.pprint()

x_fit = np.linspace(xx[0]-0.1, xx[-1]+0.1, 1000)
y_fit = fit_func(out.beta, x_fit)

plt.errorbar(xx, dn, yerr=yer, linestyle='None', marker='x',ecolor='r')

plt.plot(x_fit, y_fit)


plt.xlabel('sin(θ/2)')
plt.ylabel('dN')

plt.show()
# Out:
# Beta: [170.50097027 -15.6456963 ]
# Beta Std Error: [22.26957817 16.460392  ]
# Beta Covariance: [[ 45780.54432156 -31569.62292569]
#  [-31569.62292569  25011.36060041]]
# Residual Variance: 0.010832857477605342
# Inverse Condition #: 0.025496084882641424
# Reason(s) for Halting:
#   Sum of squares convergence
# <img src="data:image/png;base64,..." width="640">

# %%
import numpy as np
import uncertainties
from uncertainties import ufloat
from uncertainties.umath import *
n=ufloat(4.32 ,0.01) #delta S over 2
i=ufloat(30,1)
print(n/i)
# Out:
# 0.144+/-0.005
